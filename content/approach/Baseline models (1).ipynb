# %%
import pandas as pd
df=pd.read_csv('Downloads/Traits Dataset - Sheet1.csv')
df
# Out:
#                                                Section     Page  \
# 0          Volume I 3.1.1 Discussion and Required LERs       38
# 1          Volume I 3.1.1 Discussion and Required LERs       38
# 2    Volumn I 3.4 DCISC Meetings with NRC Resident ...       49
# 3          Exhibit A (Documents Received by the DCISC)       61
# 4          Exhibit A (Documents Received by the DCISC)       61
# ..                                                 ...      ...
# 124    Volume II 3.3 Containment Structure Inspections      750
# 125  Volume II 3.7 Radiation Protection Department ...      755
# 126        Volume II 3.11 Refueling Outage 1R23 Result      760
# 127        Volume II 3.11 Refueling Outage 1R23 Result      760
# 128  Volume II, Exhibit B.3, Minutes of the October...  248-249
#
#                                        Issue Statement  \
# 0    Unit 2 LER 2021-001-00 was submitted on 9/20/2...
# 1    Unit 2 LER 2021-002-00 was submitted on 12/14/...
# ...

# %%
df=df[['Issue Statement','Safety trait(s)']]

# %%
df
# Out:
#                                        Issue Statement  \
# 0    Unit 2 LER 2021-001-00 was submitted on 9/20/2...
# 1    Unit 2 LER 2021-002-00 was submitted on 12/14/...
# 2                       Feedwater heater forced outage
# 3    ODM Held on El on Unit1 due to main turbine go...
# 4              Unit 1 ASW Pump Motor 1-01 Ground Alarm
# ..                                                 ...
# 124  For Unit 1, 28 indications were judged to exce...
# 125  The data showed that 39 radiation workers incu...
# 126  Mr. Quitter explained that the biggest challen...
# 127  The last two goals were not achieved due to th...
# 128  When operators made a routine swap of an opera...
#
#                                        Safety trait(s)
# 0    Personal Accountability;\nProblem Identificati...
# 1               Problem Identification and Resolution;
# 2                                      Work Processes;
# 3                                      Work Processes;
# ...

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# Load the dataset
data = pd.read_csv('Downloads/Traits Dataset - Sheet1.csv')

vectorizer = TfidfVectorizer()
label_encoder = LabelEncoder()
vectorizer.fit(df['Issue Statement'])
vector = vectorizer.transform(df['Issue Statement'])
X = pd.DataFrame(vector.toarray(), columns=vectorizer.get_feature_names_out())
y=label_encoder.fit_transform(data['Safety trait(s)'])

clf = LogisticRegression()

kf = KFold(n_splits=10)

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    clf.fit(X_train, y_train)

    predictions = clf.predict(X_test)

    accuracy = accuracy_score(y_test, predictions)
    print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.6153846153846154
# Accuracy: 0.38461538461538464
# Accuracy: 0.46153846153846156
# Accuracy: 0.6153846153846154
# Accuracy: 0.38461538461538464
# Accuracy: 0.38461538461538464
# Accuracy: 0.7692307692307693
# Accuracy: 0.5384615384615384
# Accuracy: 0.6153846153846154
# Accuracy: 0.3333333333333333

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold
from sklearn.metrics import silhouette_score

# Load the dataset
data = pd.read_csv('Downloads/Traits Dataset - Sheet1.csv')

# Preprocess the data (as shown in the previous answer)
# ...
vectorizer = TfidfVectorizer()
vectorizer.fit(df['Issue Statement'])
vector = vectorizer.transform(df['Issue Statement'])
X = pd.DataFrame(vector.toarray(), columns=vectorizer.get_feature_names_out())

# Initialize KMeans with 3 clusters (adjust the number of clusters as needed)
kmeans = KMeans(n_clusters=23)

# Initialize KFold with 5 splits
kf = KFold(n_splits=5)

silhouette_scores = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]

    # Fit the model
    kmeans.fit(X_train)

    # Make predictions
    predictions = kmeans.predict(X_test)

    # Calculate silhouette score
    silhouette = silhouette_score(X_test, predictions)
    silhouette_scores.append(silhouette)
    print(f'Silhouette Score: {silhouette}')
# Out:
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Silhouette Score: 0.005399272903708211
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...
